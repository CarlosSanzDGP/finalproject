# %%
#En este jupyter hay que intetar hacer que una foto ajena al dataset se convierta en un array en el formato 
#idoneo para meterlo en el modelo
import numpy as np
from PIL import Image
from matplotlib import pyplot as plt

# %%
x= Image.open("INPUT/fotocochesinternet/1.jpeg")

# %%
x
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x168 at 0x7F6D5CBF9390>

# %%
plt.imshow(x)

# %%
x.size
#queremos pasarlo de 300x168 a 64x64
# Out:
# (300, 168)

# %%
size = (64,64)
car = x.resize(size)
#tan facil como esto

# %%
car.size
# Out:
# (64, 64)

# %%
plt.imshow(car)

# %%
#una vez hecho 64x64 lo pasamos a array
im_np_prueba = np.asarray(car)
one_line_prueba=im_np_prueba.ravel()

# %%
one_line_prueba
# Out:
# array([48, 41, 33, ..., 59, 61, 47], dtype=uint8)

# %%
one_line_prueba.shape
#exactamente igual que en la prueba primera de una imagen del dataset
# Out:
# (12288,)

# %%
#OJO es una array pero no en el formato que queremos
